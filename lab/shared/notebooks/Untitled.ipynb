# %%
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# Set tracking URI to internal service
# mlflow.set_tracking_uri("http://mlflow:5001")

# %%
# Create or get experiment
mlflow.set_experiment("my-experiment")
# Out:
# <Experiment: artifact_location='s3://mlflow/1', creation_time=1765590899745, experiment_id='1', last_update_time=1765590899745, lifecycle_stage='active', name='my-experiment', tags={}>

# %%
# Load data
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Start run
with mlflow.start_run():
  # Train model
  model = RandomForestClassifier(n_estimators=100)
  model.fit(X_train, y_train)

  # Log parameters
  mlflow.log_param("n_estimators", 100)

  # Log metrics
  score = model.score(X_test, y_test)
  mlflow.log_metric("accuracy", score)

  # Log model
  mlflow.sklearn.log_model(model, "model")

  print(f"Model accuracy: {score:.4f}")
  print(f"Run ID: {mlflow.active_run().info.run_id}")
# Out:
# 2025/12/13 02:52:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model accuracy: 0.9667
# Run ID: a0eb28be88ac41ae9b1e11c23a6d7929
# 🏃 View run indecisive-koi-676 at: http://mlflow.lab/#/experiments/1/runs/a0eb28be88ac41ae9b1e11c23a6d7929
# 🧪 View experiment at: http://mlflow.lab/#/experiments/1
